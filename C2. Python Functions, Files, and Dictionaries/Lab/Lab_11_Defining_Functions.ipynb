# %% [markdown]
# # Learning Goals
# - Identify formal parameters and parameter values in a code sample
# - Predict the return value of a function given sample parameter values
# - Define functions with appropriate names for formal parameters
# - Avoid the use of global variables in function definitions by creating formal parameters for all values that are needed
# - How to create tests for functions

# %% [markdown]
# # Mechanics
#
# 1. In the following code, define a function named `test1` that sets a local variable `stuff` to be twice the input and returns the value of `stuff`:

# %%
def ______ (_____)
    stuff = 2 * _____
    _______ stuff

# %% [markdown]
# 2. Call the `test1` function

# %% [markdown]
# 3. Complete the `test2` function so that it has two parameters. It adds them up and returns the total. Invoke the function.

# %%
def test2(__________,__________):
    total = _____________________________
    _____________________________________

# %% [markdown]
#  4. Make an `assert` statement about the result of invoking `test2`

# %% [markdown]
# # `print` vs. `return`

# %% [markdown]
# 5. In your own words, describe the difference between `print` and `return` and when you should use each.

# %%
def concatenation(str1, str2):
    print(str1 + str2)
    
def addition(int1, int2):
    return int1 + int2
    
def times_two(x):
    print(x)
    return x*2

# %% [markdown]
# 6. Given the three functions above, fill in the table below to indicate what will be returned and printed:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Global and Local Variables

# %%
a = 4
def adding():
    print("x")
    c = 10
    a = c + 2    
    d = a / 2
    return d
print("y")
adding()
print(a)
print(d)
# Out:
# y
# x
# 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-30beb1fe01d0> in <module>
#       9 adding()
#      10 print(a)
# ---> 11 print(d)
#
# NameError: name 'd' is not defined

# %% [markdown]
# 7. Which will be printed first, x or y?
# 2. Draw a reference diagram to keep track of what happens during the first execution of the function
#     1. What’s the value of d?
#     2. Is the global a changed, or is the new value assigned to a local `a` ?
#     3. What value will be returned?
#     4. What will be done with that returned value?
# 3. On line 10, what will print, 4 or 12?
# 4. What will happen when I try to print `d` on line 11? Why?
# 5. Suppose we change line 4 to read `c = a`. What will happen during the execution, and why? (This one’s especially tricky!)
